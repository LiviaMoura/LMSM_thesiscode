# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
import plotly
pd.set_option('display.max_rows', None)

# %%
df = pd.read_table('Cami_200g_6s/All_concatenate_together.tsv')

# %%
df_temp = df[df['Assembly'] == 'Spades_careful']
df_temp.groupby('Reference').size()
# Out:
# Reference
# GCF_000179635.2_ASM17963v2_genomic                                                                      3
# GCF_000224085.1_ASM22408v1_genomic                                                                      3
# GCF_000235405.2_ASM23540v3_genomic GCF_001644665.1_ASM164466v1_genomic                                  2
# GCF_000304415.1_RM41_genomic GCF_000346065.1_ASM34606v1_genomic GCF_002197165.1_ASM219716v1_genomic     3
# GCF_000661895.1_ASM66189v1_genomic                                                                      3
# GCF_000818095.1_ASM81809v1_genomic                                                                      3
# GCF_000834475.1_ASM83447v1_genomic GCF_000834775.1_ASM83477v1_genomic                                   3
# GCF_001308265.1_ASM130826v1_genomic                                                                     3
# GCF_001310225.1_ASM131022v1_genomic                                                                     3
# ...

# %%
df_temp[df_temp['Reference'].str.contains('GCF_002025665.1_ASM202566v1_genomic')]
# Out:
#                         Bin_Id                             Reference  \
# 15  MAG_7_Scareful_metabat.001  GCF_002025665.1_ASM202566v1_genomic
# 16           S_care_all_bin.28  GCF_002025665.1_ASM202566v1_genomic
#
#     Completeness  Contamination  Strain_heterogeneity  n_contigs  \
# 15         99.05          15.56                 63.46        499
# 16         95.03           0.90                 50.00         97
#
#     Longest_contig  pilon_errors Category        Assembly
# 15          207792          1926  careful  Spades_careful
# 16          468769            25      all  Spades_careful

# %%
new_row = {'Bin_Id':'Not found','Reference':'GCF_002025665.1_ASM202566v1_genomic','Completeness':np.nan,'Contamination':np.nan,'Strain_heterogeneity':np.nan,'n_contigs':np.nan,'Longest_contig':np.nan,'pilon_errors':np.nan,'Category':'meta','Assembly':'Spades_careful'}
df = df.append(new_row,ignore_index=True)

# %%
df = df.sort_values(by=['Reference','Completeness','Contamination'], ascending=[False,False,True])
df
# Out:
#                           Bin_Id  \
# 0               Smeta_all_bin.35
# 1     MAG_4_Scareful_concoct.068
# 2       MAG_15_Smeta_concoct.059
# 3        MAG_4_Smeta_concoct.057
# 4    MAG_10_MH_Scare_concoct.016
# 5                  MH_all_bin.12
# 6     MAG_10_MH_Smeta_maxbin.001
# 7     MAG_15_Scareful_maxbin.001
# 8              S_care_all_bin.62
# 9     MAG_6_MH_Scare_metabat.002
# 10   MAG_20_Scareful_metabat.003
# 11                 MH_all_bin.33
# 12             S_care_all_bin.31
# 13    MAG_20_S_meta_mtwrap_bin.1
# 14    MAG_6_MH_meta_mtwrap_bin.1
# 15    MAG_7_Scareful_metabat.001
# 16             S_care_all_bin.28
# 179                    Not found
# 17    MAG_5_Scareful_concoct.010
# 18    MAG_21_Scareful_maxbin.001
# 19              Smeta_all_bin.15
# 20             S_care_all_bin.55
# 21       MAG_21_Smeta_maxbin.001
# 22        MAG_5_Smeta_maxbin.001
# 23             S_care_all_bin.26
# 24      MAG_13_Smeta_metabat.001
# 25    MAG_13_Scareful_maxbin.001
# ...

# %%
df.to_csv('Cami_200g_6s/All_concatenate_together_fixed.tsv', sep='\t', index = False)
